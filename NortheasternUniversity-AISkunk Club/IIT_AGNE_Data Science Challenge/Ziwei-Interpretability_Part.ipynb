# %% [markdown]
# ## Interpretability:
# ### 0.WHY?
# * The model must also explain how it came to the prediction (the why)
#
# __e.g.:__ You was rejected by kind of reason when you need a loan from bank, what the possibility of the rejection?
# Predicting a person’s financial status for a bank. No idea what happen: if the rejection is reasonable or with some bias in it.

# %%
from IPython.display import Image
Image(filename='image/blackbox.png')

# %% [markdown]
# #### (1). Human curiosity & learning:
# __e.g.: A self-driving car automatically detects cyclists based on a deep learning system.__
#
# It has to be 100% sure that the abstraction the system has learned is __error-free__.
# An explanation might reveal that the most important learned feature is:
# To recognize the __2 wheels of a bicycle__, and this explanation helps you think about edge cases like bicycles with side bags that cover the wheels partially.

# %%
Image(filename='image/bikes.png')

# %% [markdown]
# #### (2).Manage social interactions
# Machines have to “persuade” us, so that they can achieve their intended goal.
# __e.g.__: Predict a person’s financial status for a bank.

# %%
Image(filename='image/loan.png')

# %%
Image(filename='image/pump.png')

# %%
Image(filename='image/interIntro.png')

# %% [markdown]
# ### 1. Feature importance
# ### ?? Which features are important? Which are less important? Which are white noise....

# %% [markdown]
# #### 1.0 Intro:

# %% [markdown]
# __e.g.__: Boston housing data to predict the median value of the houses

# %%
Image(filename='image/house.png')

# %% [markdown]
# * rm is average number of rooms per dwelling.

# %% [markdown]
# #### 1.1 GO back to our Amazon Project:

# %% [markdown]
# ### 2. Coefficient in some models: GLM-Generalized Linear models:

# %% [markdown]
# #### 2.1 coefficient:
# __E.g.__: estimate a person's weight as a function of the person's height and gender.
#     You could use linear regression to estimate the respective regression coefficients from a sample of data, measuring:
#         __Height, Weight, and Observing the subjects' gender ...__
#             __Y = b0 + b1X1 + b2X2 + ... + bkXk__
#
# * bi: are the __regression coefficients__ (for variables 1 through k) computed from the data. OR: the learned feature weights
# * Y: predicted target.
#
# #### 2.0 Why coefficient:
# these linear equations have an __easy to understand interpretation__ on a modular level (i.e. the weights).

# %%
Image(filename='image/weight.png')

# %% [markdown]
# #### 2.2 Get the coefficient of Our Amazon Project:

# %% [markdown]
# ### 3. Partial Dependence Plot

# %% [markdown]
# #### 3.0: Intro:
# #### Question:
# 1. Any __Relationship__ between the target and a feature?
# 2. What kind of __Relationship__? (linear,or more complex?)
# 3. How will a variable __affect__ the model? (positively or negatively)

# %% [markdown]
# ### SO...
# ### Partial Dependence Plot helps understand varaible important in a given model.

# %% [markdown]
# #### e.g. predict the number of bikes that will be rented on a given day:
# #### WILL you rent a bike in a hot day? or rainy day? or ....?
# * Model: Random forest
# * Relationship visualization: Partial dependence plot to visualize the relationships the model has learned

# %%
Image(filename='image/plot.png')

# %% [markdown]
# #### The Partial dependence plot for the bicycle count prediction model and temperature, humidity and wind speed.
# * The largest differences can be seen in the temperature:
#     - The hotter, the more bikes are rented.
#     - This trend goes up to 20 degrees Celsius, then flattens and drops slightly at 30.
#     (Marks on the x-axis indicate the data distribution.)

# %% [markdown]
# #### 3.1 GO back to our Amazon Project:

# %% [markdown]
# * The __Variable Importance Plot__  shows us:
#     - The most important variable is HelpfulnessNumerator.
#
# * The __Partial Dependency Plot__ shows that:
#     - The more people who find the review helpful, the more likely it is a good review:
#     - This trend goes up to 40, then flattens after 120.

# %% [markdown]
# #### 3.2 Get the PDP of GBM(Gradient Boosting):
